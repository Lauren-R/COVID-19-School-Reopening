# %% [markdown]
# # School Facility Reopening

# %% [markdown]
# ## Contents:
# ### 01. Import libraries and data
# ### 02. Explore data
# ### 03. Wrangle data
# ### 04. Export data

# %% [markdown]
# ## 01. Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Ensure the charts created are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# Create path shortcut

path = r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\COVID19 School ReOpening and Students'

# %%
# Import data

sf = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'School_Facility_ReOpening_Survey.csv'))

# %% [markdown]
# ## 02. Explore data

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6042 entries, 0 to 6041
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Week                          6042 non-null   object
#  1   DistrictName                  6042 non-null   object
#  2   DistrictCode                  6042 non-null   int64
#  3   DistrictOrganizationId        6042 non-null   int64
#  4   Status                        5241 non-null   object
#  5   Model_Elementary              5228 non-null   object
#  6   Model_Middle                  5214 non-null   object
#  7   Model_High                    5186 non-null   object
#  8   GradeLevels_Remote_Phasein    916 non-null    object
#  9   StudentGroups_Remote_Phasein  1033 non-null   object
#  10  Other_Remote_Phasein          258 non-null    object
#  11  Enrollment_Elementary         6042 non-null   int64
#  12  FullTimeALE_Elementary        6042 non-null   int64
#  13  OptOut_Elementary             6042 non-null   int64
#  14  TypicalInPerson_Elementary    6042 non-null   int64
#  15  Weekly_Elementary             6042 non-null   int64
#  16  Enrollment_Middle             6042 non-null   int64
#  17  FullTimeALE_Middle            6042 non-null   int64
#  18  OptOut_Middle                 6042 non-null   int64
#  19  TypicalInPerson_Middle        6042 non-null   int64
#  20  Weekly_Middle                 6042 non-null   int64
#  21  Enrollment_High               6042 non-null   int64
#  22  FullTimeALE_High              6042 non-null   int64
#  23  OptOut_High                   6042 non-null   int64
#  24  TypicalInPerson_High          6042 non-null   int64
#  25  Weekly_High                   6042 non-null   int64
# dtypes: int64(17), object(9)
# memory usage: 1.2+ MB

# %%
# Check all columns will be displayed in notebook

pd.get_option("display.max_columns")
# Out:
# 50

# %%
# Update max columns displayed to allow for all columns in rc df

pd.set_option("display.max_columns", 50)

# %%
# Check all columns are displayed

sf.head()
# Out:
#                 Week                    DistrictName  DistrictCode  \
# 0  Week of 1/18/2021            Adna School District         21226
# 1  Week of 1/18/2021          Almira School District         22017
# 2  Week of 1/18/2021       Arlington School District         31016
# 3  Week of 1/18/2021  Asotin-Anatone School District          2420
# 4  Week of 1/18/2021          Auburn School District         17408
#
#    DistrictOrganizationId    Status               Model_Elementary  \
# 0                  100011  Complete  Typical/Traditional In-Person
# 1                  100012  Complete  Typical/Traditional In-Person
# 2                  100014  Complete                       Phase-In
# 3                  100015  Complete  Typical/Traditional In-Person
# 4                  100016  Complete          Small Groups + Remote
#
#                          Model_Middle                          Model_High  \
# 0  Partial In-Person for All Students  Partial In-Person for All Students
# 1       Typical/Traditional In-Person  Partial In-Person for All Students
# 2               Small Groups + Remote               Small Groups + Remote
# 3       Typical/Traditional In-Person  Partial In-Person for All Students
# 4               Small Groups + Remote               Small Groups + Remote
#
#                           GradeLevels_Remote_Phasein  \
# 0                                                NaN
# 1                                                NaN
# 2                    Grade K,Grade 1,Grade 2,Grade 3
# 3                                                NaN
# 4  Grade K,Grade 1,Grade 2,Grade 3,Grade 4,Grade ...
#
#                         StudentGroups_Remote_Phasein Other_Remote_Phasein  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  English Language Learners,Students with Disabi...   Connectivity Needs
# 3                                                NaN                  NaN
# 4              Low Income,Students with Disabilities                  NaN
#
#    Enrollment_Elementary  FullTimeALE_Elementary  OptOut_Elementary  \
# 0                    216                       0                  0
# 1                     48                       0                  0
# 2                   2263                       0                  0
# 3                    256                       0                  0
# 4                   7295                       0                  0
#
#    TypicalInPerson_Elementary  Weekly_Elementary  Enrollment_Middle  \
# 0                         216                216                155
# 1                          48                 48                 21
# 2                        1511               1511               1296
# 3                         246                246                144
# 4                          40                 80               3865
#
#    FullTimeALE_Middle  OptOut_Middle  TypicalInPerson_Middle  Weekly_Middle  \
# 0                   0              0                      90            155
# 1                   0              0                      21             21
# 2                   0              0                      74             74
# 3                   0              0                     136            136
# 4                   0              0                      15             30
#
#    Enrollment_High  FullTimeALE_High  OptOut_High  TypicalInPerson_High  \
# 0              212                 0            0                   130
# 1               20                 0            0                    20
# 2             1702                 0            0                   120
# 3              192                 0            0                    93
# 4             5421                 0            0                    18
#
#    Weekly_High
# 0          212
# 1           20
# 2          120
# 3           93
# 4           36

# %%
# Check df shape

sf.shape
# Out:
# (6042, 26)

# %% [markdown]
# ## 03. Wrangle data

# %%
# Check status is complete

sf.value_counts('Status')
# Out:
# Status
# Complete    5241
# dtype: int64

# %%
# Drop data that does not have a status of complete

sf = sf[sf['Status'] == 'Complete']
sf.shape
# Out:
# (5241, 26)

# %%
# Rename Week column for clarity

sf.rename(columns = {'Week Of' : 'Week'}, inplace = True)

# %%
sf.head()
# Out:
#                 Week                    DistrictName  DistrictCode  \
# 0  Week of 1/18/2021            Adna School District         21226
# 1  Week of 1/18/2021          Almira School District         22017
# 2  Week of 1/18/2021       Arlington School District         31016
# 3  Week of 1/18/2021  Asotin-Anatone School District          2420
# 4  Week of 1/18/2021          Auburn School District         17408
#
#    DistrictOrganizationId    Status               Model_Elementary  \
# 0                  100011  Complete  Typical/Traditional In-Person
# 1                  100012  Complete  Typical/Traditional In-Person
# 2                  100014  Complete                       Phase-In
# 3                  100015  Complete  Typical/Traditional In-Person
# 4                  100016  Complete          Small Groups + Remote
#
#                          Model_Middle                          Model_High  \
# 0  Partial In-Person for All Students  Partial In-Person for All Students
# 1       Typical/Traditional In-Person  Partial In-Person for All Students
# 2               Small Groups + Remote               Small Groups + Remote
# 3       Typical/Traditional In-Person  Partial In-Person for All Students
# 4               Small Groups + Remote               Small Groups + Remote
#
#                           GradeLevels_Remote_Phasein  \
# 0                                                NaN
# 1                                                NaN
# 2                    Grade K,Grade 1,Grade 2,Grade 3
# 3                                                NaN
# 4  Grade K,Grade 1,Grade 2,Grade 3,Grade 4,Grade ...
#
#                         StudentGroups_Remote_Phasein Other_Remote_Phasein  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  English Language Learners,Students with Disabi...   Connectivity Needs
# 3                                                NaN                  NaN
# 4              Low Income,Students with Disabilities                  NaN
#
#    Enrollment_Elementary  FullTimeALE_Elementary  OptOut_Elementary  \
# 0                    216                       0                  0
# 1                     48                       0                  0
# 2                   2263                       0                  0
# 3                    256                       0                  0
# 4                   7295                       0                  0
#
#    TypicalInPerson_Elementary  Weekly_Elementary  Enrollment_Middle  \
# 0                         216                216                155
# 1                          48                 48                 21
# 2                        1511               1511               1296
# 3                         246                246                144
# 4                          40                 80               3865
#
#    FullTimeALE_Middle  OptOut_Middle  TypicalInPerson_Middle  Weekly_Middle  \
# 0                   0              0                      90            155
# 1                   0              0                      21             21
# 2                   0              0                      74             74
# 3                   0              0                     136            136
# 4                   0              0                      15             30
#
#    Enrollment_High  FullTimeALE_High  OptOut_High  TypicalInPerson_High  \
# 0              212                 0            0                   130
# 1               20                 0            0                    20
# 2             1702                 0            0                   120
# 3              192                 0            0                    93
# 4             5421                 0            0                    18
#
#    Weekly_High
# 0          212
# 1           20
# 2          120
# 3           93
# 4           36

# %%
sf.describe()
# Out:
#        DistrictCode  DistrictOrganizationId  Enrollment_Elementary  \
# count   5241.000000             5241.000000            5241.000000
# mean   22096.754818            98974.317306            1618.175730
# std    11063.447095            12069.410435            3149.268015
# min        0.000000                0.000000               0.000000
# 25%    14068.000000           100082.000000             110.000000
# 50%    22017.000000           100161.000000             404.000000
# 75%    32123.000000           100242.000000            1625.000000
# max    39209.000000           106257.000000           66202.000000
#
#        FullTimeALE_Elementary  OptOut_Elementary  TypicalInPerson_Elementary  \
# count             5241.000000        5241.000000                 5241.000000
# mean                35.975005         266.019080                  836.904026
# std                166.683063         748.404331                 1879.151308
# min                  0.000000           0.000000                    0.000000
# 25%                  0.000000           1.000000                   66.000000
# 50%                  0.000000          22.000000                  228.000000
# 75%                  0.000000         154.000000                  831.000000
# max               2596.000000        7500.000000                38647.000000
#
#        Weekly_Elementary  Enrollment_Middle  FullTimeALE_Middle  \
# count        5241.000000        5241.000000         5241.000000
# mean          927.199008         818.585194           24.322648
# std          1730.769348        1445.673819          132.629461
# min             0.000000           0.000000            0.000000
# 25%            72.000000          53.000000            0.000000
# 50%           276.000000         228.000000            0.000000
# 75%          1001.000000         791.000000            0.000000
# max         16456.000000       12153.000000         2238.000000
#
#        OptOut_Middle  TypicalInPerson_Middle  Weekly_Middle  Enrollment_High  \
# count    5241.000000             5241.000000    5241.000000      5241.000000
# mean      119.654074              302.129365     386.870826      1090.261210
# std       334.600060              635.957094     774.941425      1941.958351
# min         0.000000                0.000000       0.000000         0.000000
# 25%         0.000000               22.000000      25.000000        54.000000
# 50%        10.000000               75.000000      95.000000       271.000000
# 75%        70.000000              271.000000     361.000000      1126.000000
# max      3496.000000             6596.000000    7063.000000     16000.000000
#
#        FullTimeALE_High   OptOut_High  TypicalInPerson_High   Weekly_High
# count       5241.000000   5241.000000           5241.000000   5241.000000
# mean          40.576608    187.180691            348.487312    461.100744
# std          169.601494    888.085722            784.206905    996.630298
# min            0.000000      0.000000              0.000000      0.000000
# 25%            0.000000      0.000000             19.000000     20.000000
# 50%            0.000000     10.000000             79.000000     98.000000
# 75%           12.000000     96.000000            310.000000    422.000000
# max         2189.000000  35460.000000           8710.000000  10000.000000

# %%
# Remove "Week of " in Week column

sf['Week'] = sf['Week'].str.lstrip('Week of ')

# %%
sf.head()
# Out:
#         Week                    DistrictName  DistrictCode  \
# 0  1/18/2021            Adna School District         21226
# 1  1/18/2021          Almira School District         22017
# 2  1/18/2021       Arlington School District         31016
# 3  1/18/2021  Asotin-Anatone School District          2420
# 4  1/18/2021          Auburn School District         17408
#
#    DistrictOrganizationId    Status               Model_Elementary  \
# 0                  100011  Complete  Typical/Traditional In-Person
# 1                  100012  Complete  Typical/Traditional In-Person
# 2                  100014  Complete                       Phase-In
# 3                  100015  Complete  Typical/Traditional In-Person
# 4                  100016  Complete          Small Groups + Remote
#
#                          Model_Middle                          Model_High  \
# 0  Partial In-Person for All Students  Partial In-Person for All Students
# 1       Typical/Traditional In-Person  Partial In-Person for All Students
# 2               Small Groups + Remote               Small Groups + Remote
# 3       Typical/Traditional In-Person  Partial In-Person for All Students
# 4               Small Groups + Remote               Small Groups + Remote
#
#                           GradeLevels_Remote_Phasein  \
# 0                                                NaN
# 1                                                NaN
# 2                    Grade K,Grade 1,Grade 2,Grade 3
# 3                                                NaN
# 4  Grade K,Grade 1,Grade 2,Grade 3,Grade 4,Grade ...
#
#                         StudentGroups_Remote_Phasein Other_Remote_Phasein  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  English Language Learners,Students with Disabi...   Connectivity Needs
# 3                                                NaN                  NaN
# 4              Low Income,Students with Disabilities                  NaN
#
#    Enrollment_Elementary  FullTimeALE_Elementary  OptOut_Elementary  \
# 0                    216                       0                  0
# 1                     48                       0                  0
# 2                   2263                       0                  0
# 3                    256                       0                  0
# 4                   7295                       0                  0
#
#    TypicalInPerson_Elementary  Weekly_Elementary  Enrollment_Middle  \
# 0                         216                216                155
# 1                          48                 48                 21
# 2                        1511               1511               1296
# 3                         246                246                144
# 4                          40                 80               3865
#
#    FullTimeALE_Middle  OptOut_Middle  TypicalInPerson_Middle  Weekly_Middle  \
# 0                   0              0                      90            155
# 1                   0              0                      21             21
# 2                   0              0                      74             74
# 3                   0              0                     136            136
# 4                   0              0                      15             30
#
#    Enrollment_High  FullTimeALE_High  OptOut_High  TypicalInPerson_High  \
# 0              212                 0            0                   130
# 1               20                 0            0                    20
# 2             1702                 0            0                   120
# 3              192                 0            0                    93
# 4             5421                 0            0                    18
#
#    Weekly_High
# 0          212
# 1           20
# 2          120
# 3           93
# 4           36

# %%
sf.value_counts('Week')
# Out:
# Week
# 1/25/2021    308
# 3/29/2021    289
# 3/8/2021     287
# 2/22/2021    285
# 3/1/2021     285
# 4/12/2021    283
# 5/10/2021    281
# 5/17/2021    279
# 4/26/2021    278
# 4/19/2021    278
# 5/31/2021    278
# 2/15/2021    275
# 3/15/2021    273
# 2/8/2021     273
# 1/18/2021    271
# 5/3/2021     258
# 2/1/2021     257
# 5/24/2021    252
# 3/22/2021    251
# dtype: int64

# %% [markdown]
# ## 04. Export data

# %%
# Export data as csv file

sf.to_csv(os.path.join(path,'02 Data','Prepared data','School_Facility_ReOpening_Survey - clean.csv'))
