# %% [markdown]
# # Report Card Enrollment

# %% [markdown]
# ## Contents:
# ### 01. Import libraries and data
# ### 02. Explore data
# ### 03. Clean data

# %% [markdown]
# ### 01. Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Ensure the charts created are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# Create path shortcut

path = r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\COVID19 School ReOpening and Students'

# %%
# Import data

rc = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'Report_Card_Enrollment_2020-21_School_Year.csv'))
# Out:
# C:\Users\lrutl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### 02. Explore data

# %%
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20151 entries, 0 to 20150
# Data columns (total 43 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SchoolYear                               20151 non-null  object
#  1   OrganizationLevel                        20151 non-null  object
#  2   County                                   20151 non-null  object
#  3   ESDName                                  19829 non-null  object
#  4   ESDOrganizationId                        19813 non-null  float64
#  5   DistrictCode                             20135 non-null  float64
#  6   DistrictName                             20151 non-null  object
#  7   DistrictOrganizationId                   20135 non-null  float64
#  8   SchoolCode                               15740 non-null  float64
#  9   SchoolName                               20151 non-null  object
# ...

# %%
rc.value_counts('SchoolYear')
# Out:
# SchoolYear
# 2020-21    20151
# dtype: int64

# %%
rc.value_counts('OrganizationLevel')
# Out:
# OrganizationLevel
# School      15740
# District     4395
# State          16
# dtype: int64

# %%
rc.value_counts('County')
# Out:
# County
# King            3794
# Pierce          1888
# Snohomish       1546
# Spokane         1373
# Clark           1012
# Yakima           835
# Thurston         702
# Kitsap           638
# Whatcom          564
# Benton           512
# Grant            496
# Lewis            461
# Grays Harbor     459
# Skagit           441
# Stevens          417
# Whitman          382
# Cowlitz          369
# Chelan           340
# Okanogan         326
# Clallam          322
# Franklin         309
# Klickitat        300
# Walla Walla      275
# Mason            259
# Lincoln          229
# Pacific          220
# Douglas          209
# Kittitas         202
# Jefferson        172
# Adams            168
# Island           165
# San Juan         157
# Ferry            146
# Asotin           113
# Pend Oreille     110
# Skamania         107
# Columbia          55
# Wahkiakum         31
# Garfield          31
# Multiple          16
# dtype: int64

# %%
rc.value_counts('DistrictName')
# Out:
# DistrictName
# Seattle School District No. 1          764
# Spokane School District                449
# Tacoma School District                 418
# Lake Washington School District        361
# Kent School District                   323
#                                       ...
# Bates Technical College                  8
# Innovation Schools                       8
# ESD 105 acting as a school district      8
# Impact | Salish Sea Elementary           6
# ESD 123 acting as a school district      6
# Length: 326, dtype: int64

# %%
rc.value_counts('DistrictOrganizationId')
# Out:
# DistrictOrganizationId
# 100229.0    764
# 100247.0    449
# 100261.0    418
# 100127.0    361
# 100117.0    323
#            ...
# 100004.0      8
# 106019.0      8
# 104220.0      8
# 100007.0      6
# 106254.0      6
# Length: 325, dtype: int64

# %%
rc.describe()
# Out:
#        ESDOrganizationId  DistrictCode  DistrictOrganizationId    SchoolCode  \
# count       19813.000000  20135.000000            20135.000000  15740.000000
# mean       100046.231616  22181.306928           100252.307326   3514.551779
# std           486.616594  10383.897809              725.577891   1127.500731
# min        100001.000000   1109.000000           100001.000000   1502.000000
# 25%        100003.000000  17001.000000           100084.000000   2624.000000
# 50%        100006.000000  21300.000000           100161.000000   3381.500000
# 75%        100007.000000  31103.000000           100235.000000   4365.000000
# max        105886.000000  39801.000000           106257.000000   5961.000000
#
#        SchoolOrganizationId  All Students         Female      Gender X  \
# count          15740.000000  2.015100e+04   20151.000000  20151.000000
# mean          102509.497713  3.259846e+02     157.655203      0.430649
# ...

# %%
rc.columns
# Out:
# Index(['SchoolYear', 'OrganizationLevel', 'County', 'ESDName',
#        'ESDOrganizationId', 'DistrictCode', 'DistrictName',
#        'DistrictOrganizationId', 'SchoolCode', 'SchoolName',
#        'SchoolOrganizationId', 'CurrentSchoolType', 'GradeLevel',
#        'All Students', 'Female', 'Gender X', 'Male',
#        'American Indian/ Alaskan Native', 'Asian', 'Black/ African American',
#        'Hispanic/ Latino of any race(s)',
#        'Native Hawaiian/ Other Pacific Islander', 'Two or More Races', 'White',
#        'English Language Learners', 'Highly Capable', 'Homeless', 'Low-Income',
#        'Migrant', 'Military Parent', 'Mobile', 'Section 504',
#        'Students with Disabilities', 'Non-English Language Learners',
#        'Non-Highly Capable', 'Non-Homeless', 'Non-Low Income', 'Non Migrant',
#        'Non Military Parent', 'Non Mobile', 'Non Section 504',
#        'Students without Disabilities', 'DataAsOf'],
#       dtype='object')

# %%
# Create new df with unnecessary columns removed ('ESDName','ESDOrganizationId','SchoolCode','SchoolName','SchoolOrganizationId','CurrentSchoolType','GradeLevel','DataAsOf')

rc2 = rc.drop(columns = ['ESDName','ESDOrganizationId','SchoolCode','SchoolName','SchoolOrganizationId','CurrentSchoolType','GradeLevel','DataAsOf'])

# %%
rc2.columns
# Out:
# Index(['SchoolYear', 'OrganizationLevel', 'County', 'DistrictCode',
#        'DistrictName', 'DistrictOrganizationId', 'All Students', 'Female',
#        'Gender X', 'Male', 'American Indian/ Alaskan Native', 'Asian',
#        'Black/ African American', 'Hispanic/ Latino of any race(s)',
#        'Native Hawaiian/ Other Pacific Islander', 'Two or More Races', 'White',
#        'English Language Learners', 'Highly Capable', 'Homeless', 'Low-Income',
#        'Migrant', 'Military Parent', 'Mobile', 'Section 504',
#        'Students with Disabilities', 'Non-English Language Learners',
#        'Non-Highly Capable', 'Non-Homeless', 'Non-Low Income', 'Non Migrant',
#        'Non Military Parent', 'Non Mobile', 'Non Section 504',
#        'Students without Disabilities'],
#       dtype='object')

# %%
rc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20151 entries, 0 to 20150
# Data columns (total 35 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SchoolYear                               20151 non-null  object
#  1   OrganizationLevel                        20151 non-null  object
#  2   County                                   20151 non-null  object
#  3   DistrictCode                             20135 non-null  float64
#  4   DistrictName                             20151 non-null  object
#  5   DistrictOrganizationId                   20135 non-null  float64
#  6   All Students                             20151 non-null  int64
#  7   Female                                   20151 non-null  int64
#  8   Gender X                                 20151 non-null  int64
#  9   Male                                     20151 non-null  int64
# ...

# %%
rc2.describe()
# Out:
#        DistrictCode  DistrictOrganizationId  All Students         Female  \
# count  20135.000000            20135.000000  2.015100e+04   20151.000000
# mean   22181.306928           100252.307326  3.259846e+02     157.655203
# std    10383.897809              725.577891  8.043675e+03    3890.663708
# min     1109.000000           100001.000000  1.000000e+00       0.000000
# 25%    17001.000000           100084.000000  2.700000e+01      12.000000
# 50%    21300.000000           100161.000000  6.700000e+01      32.000000
# 75%    31103.000000           100235.000000  1.680000e+02      80.000000
# max    39801.000000           106257.000000  1.094330e+06  529217.000000
#
#            Gender X           Male  American Indian/ Alaskan Native  \
# count  20151.000000   20151.000000                     20151.000000
# mean       0.430649     167.898764                         4.220039
# std       11.606777    4142.048626                       104.958254
# ...

# %% [markdown]
# ##### Drop data that is not aggrigated at district level

# %%
# Drop data that is not aggrigated at district level

rc2 = rc2[rc2['OrganizationLevel'] == 'District']

# %%
rc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4395 entries, 15756 to 20150
# Data columns (total 35 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SchoolYear                               4395 non-null   object
#  1   OrganizationLevel                        4395 non-null   object
#  2   County                                   4395 non-null   object
#  3   DistrictCode                             4395 non-null   float64
#  4   DistrictName                             4395 non-null   object
#  5   DistrictOrganizationId                   4395 non-null   float64
#  6   All Students                             4395 non-null   int64
#  7   Female                                   4395 non-null   int64
#  8   Gender X                                 4395 non-null   int64
#  9   Male                                     4395 non-null   int64
# ...

# %%
rc2.describe()
# Out:
#        DistrictCode  DistrictOrganizationId  All Students        Female  \
# count   4395.000000             4395.000000   4395.000000   4395.000000
# mean   22654.658476           100374.915586    498.397270    241.042093
# std    10869.124143             1079.819447   1950.045727    943.157781
# min     1109.000000           100001.000000      1.000000      0.000000
# 25%    14099.000000           100085.500000     23.000000     10.000000
# 50%    22204.000000           100163.000000     84.000000     40.000000
# 75%    32356.000000           100240.000000    319.500000    153.000000
# max    39801.000000           106257.000000  53997.000000  26036.000000
#
#           Gender X          Male  American Indian/ Alaskan Native  \
# count  4395.000000   4395.000000                      4395.000000
# mean      0.645734    256.709443                         6.412742
# std       5.754328   1004.476636                        27.258357
# ...

# %%
rc2.value_counts('DistrictName')
# Out:
# DistrictName
# Northport School District                  16
# Vancouver School District                  16
# Central Kitsap School District             16
# Central Valley School District             16
# Centralia School District                  16
#                                            ..
# Bates Technical College                     4
# ESD 105 acting as a school district         4
# Lake Washington Institute of Technology     4
# Impact | Salish Sea Elementary              3
# ESD 123 acting as a school district         3
# Length: 325, dtype: int64

# %%
# Check for duplicate rows

rc2_dups = rc2[rc2.duplicated()]

# %%
rc2_dups.shape
# Out:
# (7, 35)

# %%
rc2_dups
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 16820    2020-21          District    Kitsap       18801.0
# 17257    2020-21          District  Franklin       11056.0
# 19079    2020-21          District  San Juan       28010.0
# 19081    2020-21          District  San Juan       28010.0
# 19083    2020-21          District  San Juan       28010.0
# 19320    2020-21          District    Chelan        4069.0
# 19321    2020-21          District    Chelan        4069.0
#
#                               DistrictName  DistrictOrganizationId  \
# 16820  ESD 114 acting as a school district                100005.0
# 17257             Kahlotus School District                100112.0
# 19079          Shaw Island School District                100234.0
# 19081          Shaw Island School District                100234.0
# 19083          Shaw Island School District                100234.0
# 19320             Stehekin School District                100253.0
# ...

# %%
rc2[rc2['DistrictName'] == 'Stehekin School District']
# Out:
#       SchoolYear OrganizationLevel  County  DistrictCode  \
# 19317    2020-21          District  Chelan        4069.0
# 19318    2020-21          District  Chelan        4069.0
# 19319    2020-21          District  Chelan        4069.0
# 19320    2020-21          District  Chelan        4069.0
# 19321    2020-21          District  Chelan        4069.0
# 19322    2020-21          District  Chelan        4069.0
# 19323    2020-21          District  Chelan        4069.0
#
#                    DistrictName  DistrictOrganizationId  All Students  Female  \
# 19317  Stehekin School District                100253.0             1       1
# 19318  Stehekin School District                100253.0             1       0
# 19319  Stehekin School District                100253.0             2       2
# 19320  Stehekin School District                100253.0             1       1
# 19321  Stehekin School District                100253.0             1       1
# ...

# %%
# Drop duplicate rows for Stehekin School District

rc2 = rc2.drop([19317,19318,19319,19320,19321,19322])

# %%
rc2.shape
# Out:
# (4389, 35)

# %%
rc2[rc2['DistrictName'] == 'Stehekin School District']
# Out:
#       SchoolYear OrganizationLevel  County  DistrictCode  \
# 19323    2020-21          District  Chelan        4069.0
#
#                    DistrictName  DistrictOrganizationId  All Students  Female  \
# 19323  Stehekin School District                100253.0             8       6
#
#        Gender X  Male  ...  Students with Disabilities  \
# 19323         0     2  ...                           0
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 19323                              8                   8             8
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# 19323               8            8                    8           8
#
#        Non Section 504  Students without Disabilities
# 19323                8                              8
#
# [1 rows x 35 columns]

# %%
# Check for duplicate rows

rc2_dups = rc2[rc2.duplicated()]
rc2_dups
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 16820    2020-21          District    Kitsap       18801.0
# 17257    2020-21          District  Franklin       11056.0
# 19079    2020-21          District  San Juan       28010.0
# 19081    2020-21          District  San Juan       28010.0
# 19083    2020-21          District  San Juan       28010.0
#
#                               DistrictName  DistrictOrganizationId  \
# 16820  ESD 114 acting as a school district                100005.0
# 17257             Kahlotus School District                100112.0
# 19079          Shaw Island School District                100234.0
# 19081          Shaw Island School District                100234.0
# 19083          Shaw Island School District                100234.0
#
#        All Students  Female  Gender X  Male  ...  Students with Disabilities  \
# 16820             1       1         0     0  ...                           0
# ...

# %%
rc2[rc2['DistrictName'] == 'Shaw Island School District']
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 19077    2020-21          District  San Juan       28010.0
# 19078    2020-21          District  San Juan       28010.0
# 19079    2020-21          District  San Juan       28010.0
# 19080    2020-21          District  San Juan       28010.0
# 19081    2020-21          District  San Juan       28010.0
# 19082    2020-21          District  San Juan       28010.0
# 19083    2020-21          District  San Juan       28010.0
#
#                       DistrictName  DistrictOrganizationId  All Students  \
# 19077  Shaw Island School District                100234.0             1
# 19078  Shaw Island School District                100234.0             1
# 19079  Shaw Island School District                100234.0             1
# 19080  Shaw Island School District                100234.0             2
# 19081  Shaw Island School District                100234.0             1
# ...

# %%
# Drop duplicate rows for Shaw Island School District

rc2 = rc2.drop([19077,19078,19079,19080,19081,19083])

# %%
rc2[rc2['DistrictName'] == 'Shaw Island School District']
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 19082    2020-21          District  San Juan       28010.0
#
#                       DistrictName  DistrictOrganizationId  All Students  \
# 19082  Shaw Island School District                100234.0             8
#
#        Female  Gender X  Male  ...  Students with Disabilities  \
# 19082       4         0     4  ...                           0
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 19082                              8                   8             8
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# 19082               8            8                    8           8
#
#        Non Section 504  Students without Disabilities
# 19082                8                              8
#
# [1 rows x 35 columns]

# %%
# Check for duplicate rows

rc2_dups = rc2[rc2.duplicated()]
rc2_dups
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 16820    2020-21          District    Kitsap       18801.0
# 17257    2020-21          District  Franklin       11056.0
#
#                               DistrictName  DistrictOrganizationId  \
# 16820  ESD 114 acting as a school district                100005.0
# 17257             Kahlotus School District                100112.0
#
#        All Students  Female  Gender X  Male  ...  Students with Disabilities  \
# 16820             1       1         0     0  ...                           0
# 17257             1       0         0     1  ...                           0
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 16820                              1                   1             1
# 17257                              1                   1             1
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# ...

# %%
rc2[rc2['DistrictName'] == 'ESD 114 acting as a school district']
# Out:
#       SchoolYear OrganizationLevel  County  DistrictCode  \
# 16817    2020-21          District  Kitsap       18801.0
# 16818    2020-21          District  Kitsap       18801.0
# 16819    2020-21          District  Kitsap       18801.0
# 16820    2020-21          District  Kitsap       18801.0
# 16821    2020-21          District  Kitsap       18801.0
#
#                               DistrictName  DistrictOrganizationId  \
# 16817  ESD 114 acting as a school district                100005.0
# 16818  ESD 114 acting as a school district                100005.0
# 16819  ESD 114 acting as a school district                100005.0
# 16820  ESD 114 acting as a school district                100005.0
# 16821  ESD 114 acting as a school district                100005.0
#
#        All Students  Female  Gender X  Male  ...  Students with Disabilities  \
# 16817             1       1         0     0  ...                           0
# ...

# %%
# Drop duplicate rows for ESD 114 acting as a school district

rc2 = rc2.drop([16817,16818,16819,16820])

# %%
rc2[rc2['DistrictName'] == 'ESD 114 acting as a school district']
# Out:
#       SchoolYear OrganizationLevel  County  DistrictCode  \
# 16821    2020-21          District  Kitsap       18801.0
#
#                               DistrictName  DistrictOrganizationId  \
# 16821  ESD 114 acting as a school district                100005.0
#
#        All Students  Female  Gender X  Male  ...  Students with Disabilities  \
# 16821             7       4         0     3  ...                           0
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 16821                              7                   7             7
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# 16821               0            7                    7           1
#
#        Non Section 504  Students without Disabilities
# 16821                7                              7
#
# [1 rows x 35 columns]

# %%
# Check for duplicate rows

rc2_dups = rc2[rc2.duplicated()]
rc2_dups
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 17257    2020-21          District  Franklin       11056.0
#
#                    DistrictName  DistrictOrganizationId  All Students  Female  \
# 17257  Kahlotus School District                100112.0             1       0
#
#        Gender X  Male  ...  Students with Disabilities  \
# 17257         0     1  ...                           0
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 17257                              1                   1             1
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# 17257               1            1                    1           1
#
#        Non Section 504  Students without Disabilities
# 17257                1                              1
#
# [1 rows x 35 columns]

# %%
v
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 17248    2020-21          District  Franklin       11056.0
# 17249    2020-21          District  Franklin       11056.0
# 17250    2020-21          District  Franklin       11056.0
# 17251    2020-21          District  Franklin       11056.0
# 17252    2020-21          District  Franklin       11056.0
# 17253    2020-21          District  Franklin       11056.0
# 17254    2020-21          District  Franklin       11056.0
# 17255    2020-21          District  Franklin       11056.0
# 17256    2020-21          District  Franklin       11056.0
# 17257    2020-21          District  Franklin       11056.0
# 17258    2020-21          District  Franklin       11056.0
# 17259    2020-21          District  Franklin       11056.0
# 17260    2020-21          District  Franklin       11056.0
# 17261    2020-21          District  Franklin       11056.0
#
# ...

# %%
# Drop duplicate rows for Kahlotus School District

rc2 = rc2.drop([17248,17249,17250,17251,17252,17253,17254,17255,17256,17257,17258,17259,17261])

# %%
rc2[rc2['DistrictName'] == 'Kahlotus School District']
# Out:
#       SchoolYear OrganizationLevel    County  DistrictCode  \
# 17260    2020-21          District  Franklin       11056.0
#
#                    DistrictName  DistrictOrganizationId  All Students  Female  \
# 17260  Kahlotus School District                100112.0            37      20
#
#        Gender X  Male  ...  Students with Disabilities  \
# 17260         0    17  ...                           7
#
#        Non-English Language Learners  Non-Highly Capable  Non-Homeless  \
# 17260                             37                  37            32
#
#        Non-Low Income  Non Migrant  Non Military Parent  Non Mobile  \
# 17260              36           37                   37          35
#
#        Non Section 504  Students without Disabilities
# 17260               36                             30
#
# [1 rows x 35 columns]

# %%
rc.value_counts('DistrictName')
# Out:
# DistrictName
# Seattle School District No. 1          764
# Spokane School District                449
# Tacoma School District                 418
# Lake Washington School District        361
# Kent School District                   323
#                                       ...
# Bates Technical College                  8
# Innovation Schools                       8
# ESD 105 acting as a school district      8
# Impact | Salish Sea Elementary           6
# ESD 123 acting as a school district      6
# Length: 326, dtype: int64

# %%
rc2[rc2['DistrictName'] == 'Spokane School District']
# Out:
#       SchoolYear OrganizationLevel   County  DistrictCode  \
# 19247    2020-21          District  Spokane       32081.0
# 19248    2020-21          District  Spokane       32081.0
# 19249    2020-21          District  Spokane       32081.0
# 19250    2020-21          District  Spokane       32081.0
# 19251    2020-21          District  Spokane       32081.0
# 19252    2020-21          District  Spokane       32081.0
# 19253    2020-21          District  Spokane       32081.0
# 19254    2020-21          District  Spokane       32081.0
# 19255    2020-21          District  Spokane       32081.0
# 19256    2020-21          District  Spokane       32081.0
# 19257    2020-21          District  Spokane       32081.0
# 19258    2020-21          District  Spokane       32081.0
# 19259    2020-21          District  Spokane       32081.0
# 19260    2020-21          District  Spokane       32081.0
# 19261    2020-21          District  Spokane       32081.0
#
# ...
