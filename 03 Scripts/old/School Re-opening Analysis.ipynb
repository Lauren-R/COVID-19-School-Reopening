# %% [markdown]
# # School Re-opening Analysis

# %% [markdown]
# ## Contents:

# %% [markdown]
# #### 01. Import libraries and data
# #### 02. Clean data
# #### 03. Descriptive analysis

# %% [markdown]
# ## 01. Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Import data

data = pd.read_csv(r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\School ReOpening\02 Data\Original Data\School_Facility_ReOpening_Survey.csv')

# %%
# Create path shortcut

path = r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\School ReOpening'

# %%
# Check import

data.head()
# Out:
#                 Week                    DistrictName  DistrictCode  \
# 0  Week of 1/18/2021            Adna School District         21226
# 1  Week of 1/18/2021          Almira School District         22017
# 2  Week of 1/18/2021       Arlington School District         31016
# 3  Week of 1/18/2021  Asotin-Anatone School District          2420
# 4  Week of 1/18/2021          Auburn School District         17408
#
#    DistrictOrganizationId    Status               Model_Elementary  \
# 0                  100011  Complete  Typical/Traditional In-Person
# 1                  100012  Complete  Typical/Traditional In-Person
# 2                  100014  Complete                       Phase-In
# 3                  100015  Complete  Typical/Traditional In-Person
# 4                  100016  Complete          Small Groups + Remote
#
#                          Model_Middle                          Model_High  \
# 0  Partial In-Person for All Students  Partial In-Person for All Students
# ...

# %%
# Check import

data.tail()
# Out:
#                    Week                       DistrictName  DistrictCode  \
# 6037  Week of 5/31/2021                Lummi Tribal Agency         37903
# 6038  Week of 5/31/2021    Quileute Tribal School District          5903
# 6039  Week of 5/31/2021          Innovation Charter School         36901
# 6040  Week of 5/31/2021  Rainier Valley Leadership Academy         17910
# 6041  Week of 5/31/2021       Yakama Nation Tribal Compact         39901
#
#       DistrictOrganizationId Status Model_Elementary Model_Middle Model_High  \
# 6037                  105800    NaN              NaN          NaN        NaN
# 6038                  105979    NaN              NaN          NaN        NaN
# 6039                  106019    NaN              NaN          NaN        NaN
# 6040                  106046    NaN              NaN          NaN        NaN
# 6041                  106181    NaN              NaN          NaN        NaN
#
# ...

# %%
# Check import

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6042 entries, 0 to 6041
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Week                          6042 non-null   object
#  1   DistrictName                  6042 non-null   object
#  2   DistrictCode                  6042 non-null   int64
#  3   DistrictOrganizationId        6042 non-null   int64
#  4   Status                        5241 non-null   object
#  5   Model_Elementary              5228 non-null   object
#  6   Model_Middle                  5214 non-null   object
#  7   Model_High                    5186 non-null   object
#  8   GradeLevels_Remote_Phasein    916 non-null    object
#  9   StudentGroups_Remote_Phasein  1033 non-null   object
#  10  Other_Remote_Phasein          258 non-null    object
#  11  Enrollment_Elementary         6042 non-null   int64
# ...

# %%
# Check import

data.dtypes
# Out:
# Week                            object
# DistrictName                    object
# DistrictCode                     int64
# DistrictOrganizationId           int64
# Status                          object
# Model_Elementary                object
# Model_Middle                    object
# Model_High                      object
# GradeLevels_Remote_Phasein      object
# StudentGroups_Remote_Phasein    object
# Other_Remote_Phasein            object
# Enrollment_Elementary            int64
# FullTimeALE_Elementary           int64
# OptOut_Elementary                int64
# TypicalInPerson_Elementary       int64
# Weekly_Elementary                int64
# Enrollment_Middle                int64
# FullTimeALE_Middle               int64
# OptOut_Middle                    int64
# TypicalInPerson_Middle           int64
# Weekly_Middle                    int64
# Enrollment_High                  int64
# FullTimeALE_High                 int64
# OptOut_High                      int64
# ...

# %%
# Check import

data.columns
# Out:
# Index(['Week', 'DistrictName', 'DistrictCode', 'DistrictOrganizationId',
#        'Status', 'Model_Elementary', 'Model_Middle', 'Model_High',
#        'GradeLevels_Remote_Phasein', 'StudentGroups_Remote_Phasein',
#        'Other_Remote_Phasein', 'Enrollment_Elementary',
#        'FullTimeALE_Elementary', 'OptOut_Elementary',
#        'TypicalInPerson_Elementary', 'Weekly_Elementary', 'Enrollment_Middle',
#        'FullTimeALE_Middle', 'OptOut_Middle', 'TypicalInPerson_Middle',
#        'Weekly_Middle', 'Enrollment_High', 'FullTimeALE_High', 'OptOut_High',
#        'TypicalInPerson_High', 'Weekly_High'],
#       dtype='object')

# %% [markdown]
# ## 02. Clean data

# %%
# Find missing values

data.isnull().sum()
# Out:
# Week                               0
# DistrictName                       0
# DistrictCode                       0
# DistrictOrganizationId             0
# Status                           801
# Model_Elementary                 814
# Model_Middle                     828
# Model_High                       856
# GradeLevels_Remote_Phasein      5126
# StudentGroups_Remote_Phasein    5009
# Other_Remote_Phasein            5784
# Enrollment_Elementary              0
# FullTimeALE_Elementary             0
# OptOut_Elementary                  0
# TypicalInPerson_Elementary         0
# Weekly_Elementary                  0
# Enrollment_Middle                  0
# FullTimeALE_Middle                 0
# OptOut_Middle                      0
# TypicalInPerson_Middle             0
# Weekly_Middle                      0
# Enrollment_High                    0
# FullTimeALE_High                   0
# OptOut_High                        0
# TypicalInPerson_High               0
# ...

# %% [markdown]
# ##### There are 7 columns with missing data. I am going to leave these as-is for now.

# %%
# Find duplicates

data_dups = data[data.duplicated()]

# %%
data_dups.shape
# Out:
# (0, 26)

# %% [markdown]
# ##### No duplicates

# %%
# Check for columns with mixed data types

for col in data.columns.tolist():
      weird = (data[[col]].applymap(type) != data[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (data[weird]) > 0:
        print (col)
# Out:
# Status
# Model_Elementary
# Model_Middle
# Model_High
# GradeLevels_Remote_Phasein
# StudentGroups_Remote_Phasein
# Other_Remote_Phasein

# %%
# Change Status column to string data type

data['Status'] = data['Status'].astype('str')

# %%
# Change Model_Elementary column to string data type

data['Model_Elementary'] = data['Model_Elementary'].astype('str')

# %%
# Change Model_Middle column to string data type

data['Model_Middle'] = data['Model_Middle'].astype('str')

# %%
# Change Model_High column to string data type

data['Model_High'] = data['Model_High'].astype('str')

# %%
# Change GradeLevels_Remote_Phasein column to string data type

data['GradeLevels_Remote_Phasein'] = data['GradeLevels_Remote_Phasein'].astype('str')

# %%
# Change StudentGroups_Remote_Phasein column to string data type

data['StudentGroups_Remote_Phasein'] = data['StudentGroups_Remote_Phasein'].astype('str')

# %%
# Change Other_Remote_Phasein column to string data type

data['Other_Remote_Phasein'] = data['Other_Remote_Phasein'].astype('str')

# %%
# Check columns with mixed data types fixed

for col in data.columns.tolist():
      weird = (data[[col]].applymap(type) != data[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (data[weird]) > 0:
        print (col)

# %% [markdown]
# ##### No mixed type data

# %% [markdown]
# ## 03. Descriptive analysis

# %%
# Basic descriptive analysis

data.describe()
# Out:
#        DistrictCode  DistrictOrganizationId  Enrollment_Elementary  \
# count   6042.000000             6042.000000            6042.000000
# mean   22328.751572            99244.871069            1403.650943
# std    11050.177496            11287.245662            2983.957908
# min        0.000000                0.000000               0.000000
# 25%    14077.000000           100085.000000              46.000000
# 50%    22045.000000           100164.500000             309.000000
# 75%    32326.000000           100244.000000            1280.000000
# max    39901.000000           106257.000000           66202.000000
#
#        FullTimeALE_Elementary  OptOut_Elementary  TypicalInPerson_Elementary  \
# count             6042.000000        6042.000000                 6042.000000
# mean                31.205727         230.752400                  725.953989
# std                155.718358         702.837958                 1773.006089
# ...

# %%
# Export data as csv file

data.to_csv(os.path.join(path,'02 Data','Prepared data','School_Facility_ReOpening_Survey.csv'))

(os.path.join(r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\School ReOpening\02 Data\Prepared Data\data_clean.csv'))
