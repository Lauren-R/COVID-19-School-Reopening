# %% [markdown]
# # Exercise 6.2_COVID19 School Re-Opening and Students

# %% [markdown]
# ## Contents:
# #### 01. Import libraries and data
# #### 02. Explore relationships

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Check matplotlib version

matplotlib.__version__
# Out:
# '3.3.4'

# %%
# Ensure the charts created are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# Create path shortcut

path = r'C:\Users\lrutl\OneDrive\Desktop\Advanced Analytics & Dashboard Design\COVID19 School ReOpening and Students'

# %%
# Import df_merged data

df_merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared data', 'df_merged_v2.csv'))

# %%
# Check import

df_merged.head()
# Out:
#    Unnamed: 0    Week Of          DistrictName  DistrictCode_x  \
# 0           0  1/18/2021  Adna School District         21226.0
# 1           1  1/18/2021  Adna School District         21226.0
# 2           2  1/18/2021  Adna School District         21226.0
# 3           3  1/18/2021  Adna School District         21226.0
# 4           4  1/18/2021  Adna School District         21226.0
#
#    DistrictOrganizationId_x    Status               Model_Elementary  \
# 0                  100011.0  Complete  Typical/Traditional In-Person
# 1                  100011.0  Complete  Typical/Traditional In-Person
# 2                  100011.0  Complete  Typical/Traditional In-Person
# 3                  100011.0  Complete  Typical/Traditional In-Person
# 4                  100011.0  Complete  Typical/Traditional In-Person
#
#                          Model_Middle                          Model_High  \
# 0  Partial In-Person for All Students  Partial In-Person for All Students
# ...

# %%
# Check import

df_merged.shape
# Out:
# (363359, 62)

# %%
# Check import

df_merged.columns
# Out:
# Index(['Unnamed: 0', 'Week Of', 'DistrictName', 'DistrictCode_x',
#        'DistrictOrganizationId_x', 'Status', 'Model_Elementary',
#        'Model_Middle', 'Model_High', 'Enrollment_Elementary',
#        'FullTimeALE_Elementary', 'OptOut_Elementary',
#        'TypicalInPerson_Elementary', 'Weekly_Elementary', 'Enrollment_Middle',
#        'FullTimeALE_Middle', 'OptOut_Middle', 'TypicalInPerson_Middle',
#        'Weekly_Middle', 'Enrollment_High', 'FullTimeALE_High', 'OptOut_High',
#        'TypicalInPerson_High', 'Weekly_High', 'SchoolYear',
#        'OrganizationLevel', 'County', 'ESDName', 'ESDOrganizationId',
#        'DistrictCode_y', 'DistrictOrganizationId_y', 'CurrentSchoolType',
#        'GradeLevel', 'All Students', 'Female', 'Gender X', 'Male',
#        'American Indian/ Alaskan Native', 'Asian', 'Black/ African American',
#        'Hispanic/ Latino of any race(s)',
#        'Native Hawaiian/ Other Pacific Islander', 'Two or More Races', 'White',
# ...

# %%
# Drop columns not needed for analysis

df_merged = df_merged.drop(columns = ['Unnamed: 0'])

# %%
# Drop columns not needed for analysis

df_merged = df_merged.drop(columns = ['DistrictCode_x'])
df_merged = df_merged.drop(columns = ['DistrictOrganizationId_x'])

# %% [markdown]
# ## 02. Explore relationships

# %%
# Review basic descriptive statistics

df_merged.describe()
# Out:
#        Enrollment_Elementary  FullTimeALE_Elementary  OptOut_Elementary  \
# count          363359.000000           363359.000000      363359.000000
# mean             3938.303427               50.402395         729.421778
# std              4717.465305              167.846026        1323.786556
# min                 0.000000                0.000000           0.000000
# 25%               282.000000                0.000000           1.000000
# 50%              1914.000000                0.000000         109.000000
# 75%              6569.000000               18.000000         825.000000
# max             66202.000000             2596.000000        7500.000000
#
#        TypicalInPerson_Elementary  Weekly_Elementary  Enrollment_Middle  \
# count               363359.000000      363359.000000      363359.000000
# mean                  1984.913672        2068.130284        1902.551023
# std                   3291.259156        2896.017035        2064.073723
# ...

# %%
# Create a correlation matrix using pandas

df_merged.corr()
# Out:
#                                          Enrollment_Elementary  \
# Enrollment_Elementary                                 1.000000
# FullTimeALE_Elementary                                0.093843
# OptOut_Elementary                                     0.614320
# TypicalInPerson_Elementary                            0.643417
# Weekly_Elementary                                     0.679626
# Enrollment_Middle                                     0.905317
# FullTimeALE_Middle                                    0.056824
# OptOut_Middle                                         0.490021
# TypicalInPerson_Middle                                0.544763
# Weekly_Middle                                         0.530063
# Enrollment_High                                       0.921859
# FullTimeALE_High                                      0.176841
# OptOut_High                                           0.292810
# TypicalInPerson_High                                  0.542112
# ...

# %%
# Group data for analysis

group1 = df_merged[['OptOut_Elementary','OptOut_Middle','OptOut_High','Weekly_Elementary','Weekly_Middle','Weekly_High','American Indian/ Alaskan Native','Asian','Black/ African American','Hispanic/ Latino of any race(s)','Native Hawaiian/ Other Pacific Islander','Two or More Races','White']]

group1
# Out:
#         OptOut_Elementary  OptOut_Middle  OptOut_High  Weekly_Elementary  \
# 0                       0              0            0                216
# 1                       0              0            0                216
# 2                       0              0            0                216
# 3                       0              0            0                216
# 4                       0              0            0                216
# ...                   ...            ...          ...                ...
# 363354                  0              1            3                  0
# 363355                  0              1            3                  0
# 363356                  0              1            3                  0
# 363357                  0              1            3                  0
# 363358                  0              1            3                  0
#
#         Weekly_Middle  Weekly_High  American Indian/ Alaskan Native  Asian  \
# ...

# %%
# Create a correlation matrix using pandas

group1.corr()
# Out:
#                                          OptOut_Elementary  OptOut_Middle  \
# OptOut_Elementary                                 1.000000       0.771472
# OptOut_Middle                                     0.771472       1.000000
# OptOut_High                                       0.523871       0.623136
# Weekly_Elementary                                 0.480271       0.479607
# Weekly_Middle                                     0.392955       0.507312
# Weekly_High                                       0.338902       0.386609
# American Indian/ Alaskan Native                  -0.027235      -0.020723
# Asian                                             0.121793       0.077230
# Black/ African American                           0.093426       0.079727
# Hispanic/ Latino of any race(s)                   0.033595       0.040695
# Native Hawaiian/ Other Pacific Islander           0.079256       0.078983
# Two or More Races                                 0.077142       0.067903
# ...

# %% [markdown]
# ## Create a correlation matrix heatmap (colored)

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(group1.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(12, 12)) # figure size 
plt.matshow(group1.corr(), fignum=f.number) # type of plot
plt.xticks(range(group1.shape[1]), group1.columns, fontsize=10, rotation=90) # x axis labels
plt.yticks(range(group1.shape[1]), group1.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix Heatmap', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %% [markdown]
# ## The coefficients in this plot indicate there is virtually no relationship between attendance and student demographics during COVID19.

# %%
f2,ax = plt.subplots(figsize=(20,20))

# %%
#  Add correlation numbers to graph for clarity

f2 = sns.heatmap(group1.corr(), annot = True, ax = ax) 
f2.figure
